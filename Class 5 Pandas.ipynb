# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# 2                5           8.0          10.0                   10
# 3                7           NaN           2.0                    2
# 4                7           7.0           9.0                    9
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 0                    45        25.0           70     B
# 1                    32        18.0           50     F
# ...

# %%
data[data['Assignment 1'] >= 7]
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# ...

# %%
data[data['Assignment 1'] >= 7].count()
# Out:
# Student Code            38
# Degree                  38
# Student Name            38
# Mid                     38
# Quiz 1                  36
# Quiz 2                  37
# Best of Quizzes         38
# Assignment 1            38
# Assignment 2            29
# Best of Assignments     38
# Total Sessional (50)    38
# Final (50)              38
# Total (100)             38
# Grade                   38
# dtype: int64

# %%
data[(data['Assignment 1'] >= 7) & (data['Assignment 2'] >= 7)]
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# ...

# %%
data[(data['Assignment 1'] >= 7) & (data['Assignment 2'] >= 7)].count()
# Out:
# Student Code            29
# Degree                  29
# Student Name            29
# Mid                     29
# Quiz 1                  27
# Quiz 2                  28
# Best of Quizzes         29
# Assignment 1            29
# Assignment 2            29
# Best of Assignments     29
# Total Sessional (50)    29
# Final (50)              29
# Total (100)             29
# Grade                   29
# dtype: int64

# %%
data['Assignment 2'][data['Assignment 1'] >= 7]
# Out:
# 0      9.0
# 1     10.0
# 2     10.0
# 4      9.0
# 5     10.0
# 6     10.0
# 7     10.0
# 8      9.0
# 9      NaN
# 10     NaN
# 12    10.0
# 13    10.0
# 16     9.0
# 17    11.0
# 18    10.0
# 19    10.0
# 20     9.0
# 21    11.0
# 22     NaN
# 23    10.0
# 24    11.0
# 25    10.0
# 27    10.0
# 28    11.0
# 30     NaN
# 31     NaN
# 32    10.0
# 33    10.0
# 34    10.0
# 36     NaN
# 37     NaN
# 39    11.0
# 40    10.0
# 41    10.0
# 42    10.0
# 44     NaN
# 45     NaN
# 46    10.0
# Name: Assignment 2, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 14 columns):
# Student Code            48 non-null object
# Degree                  48 non-null object
# Student Name            48 non-null object
# Mid                     48 non-null int64
# Quiz 1                  45 non-null float64
# Quiz 2                  45 non-null float64
# Best of Quizzes         48 non-null int64
# Assignment 1            45 non-null float64
# Assignment 2            36 non-null float64
# Best of Assignments     48 non-null int64
# Total Sessional (50)    48 non-null int64
# Final (50)              47 non-null float64
# Total (100)             48 non-null int64
# Grade                   48 non-null object
# dtypes: float64(5), int64(5), object(4)
# memory usage: 5.3+ KB

# %%
data.describe()
# Out:
#              Mid     Quiz 1     Quiz 2  Best of Quizzes  Assignment 1  \
# count  48.000000  45.000000  45.000000        48.000000     45.000000
# mean   22.937500   7.288889   4.866667         7.020833      7.755556
# std     5.236558   1.561209   1.455397         1.973113      1.170772
# min     9.000000   4.000000   1.000000         0.000000      5.000000
# 25%    20.000000   6.000000   4.000000         6.000000      7.000000
# 50%    25.000000   8.000000   5.000000         7.000000      8.000000
# 75%    27.000000   9.000000   6.000000         9.000000      8.000000
# max    30.000000   9.000000   7.000000         9.000000     10.000000
#
#        Assignment 2  Best of Assignments  Total Sessional (50)  Final (50)  \
# count     36.000000            48.000000             48.000000   47.000000
# mean       9.444444             8.937500             38.895833   27.851064
# std        1.629100             2.127892              7.179283    8.431253
# ...

# %%
st = "Hello World"
st.startswith("Hello")
# Out:
# True

# %%
data[(data['Assignment 1'] >= 7) & (data['Assignment 2'] >= 7)]['Student Name']
# Out:
# 0                        Abdul Basit
# 1                        Adeel Ahmed
# 2                       Afrah Zareen
# 4                    Ahsan Ali Vohra
# 5                        Ameer Hamza
# 6                      Anas Ali Khan
# 7                   Aneebullah Niazi
# 8                     Areesha Sohail
# 12               Hafiza Tooba Akbani
# 13                Hamza Abdul Jabbar
# 16                      Hassam Ahmed
# 17                      Khalid Anwer
# 18                     Madiha Jabeen
# 19                   Mohammad Hunain
# 20                    Muhammad Aamir
# 21    Muhammad Abdul Rehman Siddiqui
# 23                Muhammad Ali Iqbal
# 24                    Muhammad Bilal
# 25                    Muhammad Faraz
# 27               Muhammad Osama Khan
# 28            Muhammad Saqib Intizar
# 32             Muhammad Wajahat Khan
# 33              Muhammad Younus Baig
# 34                  Nazeer Bin Zafar
# 39                       Sania Iqbal
# ...

# %%
data[(data['Assignment 1'] >= 7) & (data['Assignment 2'] >= 7) & 
     (data['Student Name'].str.startswith("Muhammad")) | 
     (data['Student Name'].str.startswith("Mohammad"))]['Student Name']
# Out:
# 19                   Mohammad Hunain
# 20                    Muhammad Aamir
# 21    Muhammad Abdul Rehman Siddiqui
# 23                Muhammad Ali Iqbal
# 24                    Muhammad Bilal
# 25                    Muhammad Faraz
# 27               Muhammad Osama Khan
# 28            Muhammad Saqib Intizar
# 32             Muhammad Wajahat Khan
# 33              Muhammad Younus Baig
# Name: Student Name, dtype: object

# %%
obj = pd.Series(range(6), index=['d', 'a', 'b', 'c','1','A'])

# %%
frame = pd.DataFrame(np.arange(24).reshape((4, 6)), index=['three', 'one','1','2'], 
                     columns=['d', 'a', 'b', 'c','1','A'])

# %%
obj.sort_index()
# Out:
# 1    4
# A    5
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
obj.sort_values()
# Out:
# d    0
# a    1
# b    2
# c    3
# 1    4
# A    5
# dtype: int64

# %%
chr(100)
# Out:
# 'd'

# %%
frame
# Out:
#         d   a   b   c   1   A
# three   0   1   2   3   4   5
# one     6   7   8   9  10  11
# 1      12  13  14  15  16  17
# 2      18  19  20  21  22  23

# %%
frame.sort_index()
# Out:
#         d   a   b   c   1   A
# 1      12  13  14  15  16  17
# 2      18  19  20  21  22  23
# one     6   7   8   9  10  11
# three   0   1   2   3   4   5

# %%
frame.sort_index(axis=1, inplace=True)

# %%
frame
# Out:
#         1   A   a   b   c   d
# three   4   5   1   2   3   0
# one    10  11   7   8   9   6
# 1      16  17  13  14  15  12
# 2      22  23  19  20  21  18

# %%
frame.sort_index(axis=1, ascending=False)
# Out:
#         d   c   b   a   A   1
# three   0   3   2   1   5   4
# one     6   9   8   7  11  10
# 1      12  15  14  13  17  16
# 2      18  21  20  19  23  22

# %%
data.sort_values(by="Mid")
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 38  022-14-110229  BS(CS)                Sadaquat Rafique    9     6.0
# 47  022-14-110219  BS(CS)                     Waqar Ahmed   11     9.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 29  022-14-110217  BS(CS)       Muhammad Shahroz Khurshid   17     7.0
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     NaN
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 35   022-14-19923  BS(CS)                      Rabi Ahmed   20     8.0
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# ...

# %%
data.sort_values(by=["Mid","Best of Quizzes"])
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 38  022-14-110229  BS(CS)                Sadaquat Rafique    9     6.0
# 47  022-14-110219  BS(CS)                     Waqar Ahmed   11     9.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 29  022-14-110217  BS(CS)       Muhammad Shahroz Khurshid   17     7.0
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 22  022-14-110398  BS(CS)               Muhammad Abdullah   20     7.0
# ...

# %%
obj = pd.Series([7, -5, 7, 4, 2, 0, 4, 7])
obj.sort_values(inplace=True)
obj
# Out:
# 1   -5
# 5    0
# 4    2
# 3    4
# 6    4
# 0    7
# 2    7
# 7    7
# dtype: int64

# %%
obj.rank(method="first")
# Out:
# 1    1.0
# 5    2.0
# 4    3.0
# 3    4.0
# 6    5.0
# 0    6.0
# 2    7.0
# 7    8.0
# dtype: float64

# %%
obj.rank()
# Out:
# 1    1.0
# 5    2.0
# 4    3.0
# 3    4.5
# 6    4.5
# 0    7.0
# 2    7.0
# 7    7.0
# dtype: float64

# %%
data['Mid'].idxmax()
# Out:
# 10

# %%
data[['Mid','Best of Quizzes']]
# Out:
#     Mid  Best of Quizzes
# 0    28                8
# 1    17                5
# 2    18                5
# 3    14                7
# 4    27                7
# 5    25                9
# 6    28                6
# 7    26                9
# 8    19                9
# 9    28                8
# 10   30                8
# 11   28                8
# 12   23                7
# 13   24                8
# 14   21                7
# 15   18                0
# 16   23                5
# 17   20                8
# 18   16                5
# 19   27                9
# 20   24                7
# 21   20                9
# 22   20                7
# 23   26                5
# 24   28                5
# 25   26                9
# 26   27                6
# 27   27                8
# 28   22                6
# 29   17                7
# 30   23                8
# 31   27                7
# 32    9                2
# 33   20                4
# 34   25                9
# 35   20                8
# ...

# %%
frame
# Out:
#         1   A   a   b   c   d
# three   4   5   1   2   3   0
# one    10  11   7   8   9   6
# 1      16  17  13  14  15  12
# 2      22  23  19  20  21  18

# %%
frame.cumsum()
# Out:
#         1   A   a   b   c   d
# three   4   5   1   2   3   0
# one    14  16   8  10  12   6
# 1      30  33  21  24  27  18
# 2      52  56  40  44  48  36

# %%
frame['A'].isin(['5'])
# Out:
# three     True
# one      False
# 1        False
# 2        False
# Name: A, dtype: bool

# %%
data[data['Assignment 1'] == 8]
# Out:
#      Student Code  Degree           Student Name  Mid  Quiz 1  Quiz 2  \
# 1   022-14-110233  BS(CS)            Adeel Ahmed   17     NaN     5.0
# 2   022-14-110585  BS(CS)           Afrah Zareen   18     5.0     2.0
# 5   022-14-110232  BS(CS)            Ameer Hamza   25     9.0     6.0
# 6   022-14-110588  BS(CS)          Anas Ali Khan   28     5.0     6.0
# 7   022-14-110388  BS(CS)       Aneebullah Niazi   26     9.0     6.0
# 9   022-14-110599  BS(CS)                Arsalan   28     8.0     6.0
# 10  022-14-110214  BS(CS)    Fatima Haider Warsi   30     8.0     7.0
# 12  022-15-110994  BS(CS)    Hafiza Tooba Akbani   23     7.0     5.0
# 13  022-14-110600  BS(CS)     Hamza Abdul Jabbar   24     8.0     4.0
# 18  022-14-110223  BS(CS)          Madiha Jabeen   16     5.0     2.0
# 19  022-14-110222  BS(CS)        Mohammad Hunain   27     9.0     6.0
# 23   022-14-19983  BS(CS)     Muhammad Ali Iqbal   26     5.0     NaN
# ...

# %%
data[data['Assignment 1'].isin([8,9])]
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
# 24  022-14-110215  BS(CS)                  Muhammad Bilal   28     5.0
# 28  022-14-110387  BS(CS)          Muhammad Saqib Intizar   22     6.0
# 30  022-14-110401  BS(CS)                 Muhammad Shozab   23     8.0
# 31  022-14-110231  BS(CS)           Muhammad Taha Hasnain   27     7.0
# 36  022-14-110582  BS(CS)                      Rida Nasim   25     9.0
# 37  022-14-110230  BS(CS)                   Sadaf Nosheen   27     9.0
# 39  022-14-110107  BS(CS)                     Sania Iqbal   28     4.0
# 44  022-14-110589  BS(CS)                     Syed Sohaib   25     7.0
# 45  022-14-110400  BS(CS)               Syeda Sabika Raza   27     9.0
#
#     Quiz 2  Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# ...

# %%
data[data['Student Name'].isin(["Muhammad Abdul Rehman Siddiqui"])]
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
#
#     Quiz 2  Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 21     6.0                9           9.0          11.0                   11
#
#     Total Sessional (50)  Final (50)  Total (100) Grade
# 21                    40        20.0           60     C
